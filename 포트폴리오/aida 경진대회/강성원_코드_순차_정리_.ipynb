# %% [markdown]
# # gpu 환경 설정

# %%
# 할당된 gpu보기
from tensorflow.python.client import device_lib

device_lib.list_local_devices()

# %%
# 사용가능한 gpu 목록
# 현재 할당된 것이 cpu인지 gpu인지 확인 
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU')

# %%
# 할당된 gpu를 실행 
import os 

os.environ["CUDA_VISIBLE_DEVICES"]="0"
gpus=tf.config.experimental.list_physical_devices("GPU")

if gpus:
  try:
    # GPU 메모리 사용을 설정 
    tf.config.experimental.set_memory_growth(gpus[0],True)

  except RuntimeError as re:
    print(re)

# %%
# gpu 메모리를 전부 할당하지 않고 필요에 따라 자동으로 할당하도록 설정 
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth=True
session=InteractiveSession(config=config)

# %% [markdown]
# # 공유 드라이브에 있는 파일 가져오기 (드라이브 마운트)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 드라이브에서 이미지 파일 가져와서 정리하는 코드

# %%
#1. 이미지 데이터가 압축 파일 형태로 저장되어있어서 읽어올때 풀어야 한다. (damage)

from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/1.Training/1.원천데이터/TS_damage.zip",).extractall("/content/damage_image")

# %%
#1. 이미지 데이터가 압축 파일 형태로 저장되어있어서 읽어올때 풀어야 한다. (damage_part)

from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/1.Training/1.원천데이터/TS_damage_part.zip",).extractall("/content/damage_part_image")

# %% [markdown]
# ## validation 이미지 데이터도 마찬가지로 가져와서 정리

# %%
from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/2.Validation/1.원천데이터/VS_damage.zip",).extractall("/content/val/damage_image")

# %%
from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/2.Validation/1.원천데이터/VS_damage_part.zip",).extractall("/content/val/damage_part_image")

# %% [markdown]
# # 라벨링 데이터를 가져와서 정리하는 코드

# %%
from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/1.Training/2.라벨링데이터/TL_damage.zip",).extractall("/content/label/damage_image")

# %%
from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/1.Training/2.라벨링데이터/TL_damage_part.zip",).extractall("/content/label/damage_part_image")

# %% [markdown]
# ## validation 라벨링 데이터 정리하기

# %%
#damage 라벨링
from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/2.Validation/2.라벨링데이터/VL_damage.zip",).extractall("/content/label/val-damage_image")

# %%
#damage_part
from zipfile import ZipFile as zf
import numpy as np
from PIL import Image
from io import BytesIO
import os


zf("/content/drive/MyDrive/Data/160. 차량파손 이미지 데이터/01.데이터/2.Validation/2.라벨링데이터/VL_damage_part.zip",).extractall("/content/label/val-damage_part_image")

# %% [markdown]
# # dataset 디렉토리를 만드는 코드

# %%
# %pwd
# Out:
# '/content'

# %%
# %mkdir dataset

# %%
# %cd dataset
# Out:
# /content/dataset

# %%
# %mkdir train

# %%
# %mkdir val

# %%
# %cd train
# Out:
# /content/dataset/train

# %%
# %mkdir images

# %%
# %mkdir labels

# %%
# %cd ../
# Out:
# /content/dataset

# %%
# %pwd
# Out:
# '/content/dataset/validation'

# %%
# %mkdir images

# %%
# %mkdir labels

# %% [markdown]
# # labeling json 파일 변환하는 코드

# %%
import os
from glob import glob

# damage_labeling
label_list_json_dir1="/content/label/damage_image/damage/"
label_list_json_file1=os.listdir(label_list_json_dir)

# %%
len(label_list_json_file1)
# Out:
# 403559

# %%
import os
from glob import glob

# damage_part_labeling
label_list_json_dir2="/content/label/damage_part_image/damage_part"
label_list_json_file2=os.listdir(label_list_json_dir2)

# %%
len(label_list_json_file2)
# Out:
# 109062

# %%
import json

for file in label_list_json_file1 :
    with open(label_list_json_dir1 +"/"+file,"r") as f :
        json_data = json.load(f)
        
        f_name2 = json_data["images"]["file_name"][:-4]
        width = json_data["images"]["width"]  # 이미지 너비
        height = json_data["images"]["height"]  # 이미지 높이
        
        with open(f"/content/label/damage_image/{f_name2}.txt", 'w') as f1 :
           for d in json_data['annotations']:
                x1, y1, x2, y2 = d["bbox"]  # bbox의 왼쪽 상단(x1, y1), 오른쪽하단(x2, y2 좌표)
                x, y = (x1 + (x1 + x2)) / 2 / width,(y1 + (y1-y2)) / 2 / height  # YOLO 모델에 넣을 이미지에 대한 bbox 중앙점의 상대적 좌표(x, y) 
                w, h = x2 / width, y2 / height  # YOLO 모델에 넣을 bbox의 이미지에 대한 상대적 너비, 높이

                if d["damage"] == None:
                    num = 0
                elif d["damage"] == 'Crushed':
                    num = 1
                elif d["damage"] == 'Scratched':
                    num = 2
                elif d["damage"] == 'Breakage':
                    num = 3
                elif d["damage"] == 'Separated':
                    num = 4 

                bbox = ' '.join(map(str, [num, x, y, w, h]))

                if d["damage"] == None :
                    f1.write(f'0 {bbox}\n')  # txt파일에 클래스 인덱스 0 bbox값(x y w h) 쓰기                            

                # damage가 null이 아니면,
                else :
                    f1.write(f'{bbox}\n') # txt파일에 클래스 인덱스와 bbox값(x y w h) 쓰기

# %%
import json

for file in label_list_json_file2 :
    with open(label_list_json_dir2 +"/"+file,"r") as f :
        json_data = json.load(f)
        
        f_name2 = json_data["images"]["file_name"][:-4]
        width = json_data["images"]["width"]  # 이미지 너비
        height = json_data["images"]["height"]  # 이미지 높이
        
        with open(f"/content/label/damage_part_image/{f_name2}.txt", 'w') as f1 :
           for d in json_data['annotations']:
                x1, y1, x2, y2 = d["bbox"]  # bbox의 왼쪽 상단(x1, y1), 오른쪽하단(x2, y2 좌표)
                x, y = (x1 + (x1 + x2)) / 2 / width,(y1 + (y1-y2)) / 2 / height  # YOLO 모델에 넣을 이미지에 대한 bbox 중앙점의 상대적 좌표(x, y) 
                w, h = x2 / width, y2 / height  # YOLO 모델에 넣을 bbox의 이미지에 대한 상대적 너비, 높이

                if d["damage"] == None:
                    num = 0
                elif d["damage"] == 'Crushed':
                    num = 1
                elif d["damage"] == 'Scratched':
                    num = 2
                elif d["damage"] == 'Breakage':
                    num = 3
                elif d["damage"] == 'Separated':
                    num = 4 

                bbox = ' '.join(map(str, [num, x, y, w, h]))

                if d["damage"] == None :
                    f1.write(f'0 {bbox}\n')  # txt파일에 클래스 인덱스 0 bbox값(x y w h) 쓰기                            

                # damage가 null이 아니면,
                else :
                    f1.write(f'{bbox}\n') # txt파일에 클래스 인덱스와 bbox값(x y w h) 쓰기

# %% [markdown]
# # val 데이터도 전부 라벨링 변환시켜준다.

# %%
import os
from glob import glob

# damage_labeling
label_list_json_dir3="/content/label/val-damage_image/damage"
label_list_json_file3=os.listdir(label_list_json_dir3)

# %%
import os
from glob import glob

# damage_labeling
label_list_json_dir4="/content/label/val-damage_part_image/damage_part"
label_list_json_file4=os.listdir(label_list_json_dir4)

# %%
import json

for file in label_list_json_file3 :
    with open(label_list_json_dir3 +"/"+file,"r") as f :
        json_data = json.load(f)
        
        f_name2 = json_data["images"]["file_name"][:-4]
        width = json_data["images"]["width"]  # 이미지 너비
        height = json_data["images"]["height"]  # 이미지 높이
        
        with open(f"/content/label/val-damage_image/{f_name2}.txt", 'w') as f1 :
           for d in json_data['annotations']:
                x1, y1, x2, y2 = d["bbox"]  # bbox의 왼쪽 상단(x1, y1), 오른쪽하단(x2, y2 좌표)
                x, y = (x1 + (x1 + x2)) / 2 / width,(y1 + (y1-y2)) / 2 / height  # YOLO 모델에 넣을 이미지에 대한 bbox 중앙점의 상대적 좌표(x, y) 
                w, h = x2 / width, y2 / height  # YOLO 모델에 넣을 bbox의 이미지에 대한 상대적 너비, 높이

                if d["damage"] == None:
                    num = 0
                elif d["damage"] == 'Crushed':
                    num = 1
                elif d["damage"] == 'Scratched':
                    num = 2
                elif d["damage"] == 'Breakage':
                    num = 3
                elif d["damage"] == 'Separated':
                    num = 4 

                bbox = ' '.join(map(str, [num, x, y, w, h]))

                if d["damage"] == None :
                    f1.write(f'0 {bbox}\n')  # txt파일에 클래스 인덱스 0 bbox값(x y w h) 쓰기                            

                # damage가 null이 아니면,
                else :
                    f1.write(f'{bbox}\n') # txt파일에 클래스 인덱스와 bbox값(x y w h) 쓰기

# %%
import json

for file in label_list_json_file4 :
    with open(label_list_json_dir4 +"/"+file,"r") as f :
        json_data = json.load(f)
        
        f_name2 = json_data["images"]["file_name"][:-4]
        width = json_data["images"]["width"]  # 이미지 너비
        height = json_data["images"]["height"]  # 이미지 높이
        
        with open(f"/content/label/val-damage_part_image/{f_name2}.txt", 'w') as f1 :
           for d in json_data['annotations']:
                x1, y1, x2, y2 = d["bbox"]  # bbox의 왼쪽 상단(x1, y1), 오른쪽하단(x2, y2 좌표)
                x, y = (x1 + (x1 + x2)) / 2 / width,(y1 + (y1-y2)) / 2 / height  # YOLO 모델에 넣을 이미지에 대한 bbox 중앙점의 상대적 좌표(x, y) 
                w, h = x2 / width, y2 / height  # YOLO 모델에 넣을 bbox의 이미지에 대한 상대적 너비, 높이

                if d["damage"] == None:
                    num = 0
                elif d["damage"] == 'Crushed':
                    num = 1
                elif d["damage"] == 'Scratched':
                    num = 2
                elif d["damage"] == 'Breakage':
                    num = 3
                elif d["damage"] == 'Separated':
                    num = 4 

                bbox = ' '.join(map(str, [num, x, y, w, h]))

                if d["damage"] == None :
                    f1.write(f'0 {bbox}\n')  # txt파일에 클래스 인덱스 0 bbox값(x y w h) 쓰기                            

                # damage가 null이 아니면,
                else :
                    f1.write(f'{bbox}\n') # txt파일에 클래스 인덱스와 bbox값(x y w h) 쓰기

# %% [markdown]
# # 이미지 데이터 전부 복사해서 dataset train image에 옯기기

# %%
from glob import glob
import shutil

img_list1=glob("/content/damage_image/damage/*.jpg")

for i in img_list1:
  shutil.move(i, '/content/dataset/train/images' )

# %%
from glob import glob
import shutil

img_list2=glob("/content/damage_part_image/damage_part/*.jpg")

for i in img_list2:
  shutil.move(i, '/content/dataset/train/images' )

# %%
## 제대로 이동이 되었는지 확인해볼까?

dataset_check=glob('/content/dataset/train/images/*.jpg')

len(dataset_check)
# Out:
# 402143

# %% [markdown]
# ## validataion 이미지를 이동시키기

# %%
img_list3=glob("/content/val/damage_image/damage/*.jpg")

for i in img_list3:
  shutil.move(i, '/content/dataset/validation/images' )

# %%
img_list4=glob("/content/val/damage_part_image/damage_part/*.jpg")

for i in img_list4:
  shutil.move(i, '/content/dataset/validation/images' )

# %%
## 제대로 이동이 되었는지 체크해보기 

dataset_check2=glob('/content/dataset/validation/images/*.jpg')

len(dataset_check2)
# Out:
# 67693

# %% [markdown]
# ## labels 데이터 긁어오기

# %%
label_list1=glob("/content/label/damage_image/*.txt")

for i in label_list1:
  shutil.move(i, "/content/dataset/train/labels")

# %%
label_list2=glob("/content/label/damage_part_image/*.txt")

for i in label_list2:
  shutil.move(i, "/content/dataset/train/labels")

# %%
label_list3=glob("/content/label/val-damage_image/*.txt")

for i in label_list3:
  shutil.move(i, "/content/dataset/validation/labels")

# %%
label_list4=glob("/content/label/val-damage_part_image/*.txt")

for i in label_list4:
  shutil.move(i, "/content/dataset/validation/labels")

# %% [markdown]
# # dataset 다시 확인

# %%
dataset1=glob("/content/dataset/train/images/*.jpg")

len(dataset1)
# Out:
# 511205

# %%
dataset2=glob("/content/dataset/train/labels/*.txt")

len(dataset2)
# Out:
# 512621

# %%
dataset3=glob("/content/dataset/validation/images/*.jpg")

len(dataset3)
# Out:
# 67693

# %%
dataset4=glob("/content/dataset/validation/labels/*.txt")

len(dataset4)
# Out:
# 67693

# %% [markdown]
# # data.yaml 파일 만들기

# %%
data={}# 빈 딕트 

data["train"]="/content/dataset/train/images"
data["val"]="/content/dataset/val/images"

data['nc']= 5
data['names']=['None',
'Crushed',
'Scratched',
'Breakage',
'Separated']

# %%
import  yaml

with open('/content/dataset/data.yaml','w') as f:
    yaml.dump(data,f)

# %% [markdown]
# # yolov5와 yolov7 모델 클론하기

# %%
# yolo v5
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14974, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14974 (delta 6), reused 9 (delta 3), pack-reused 14960
# Receiving objects: 100% (14974/14974), 13.65 MiB | 26.13 MiB/s, done.
# Resolving deltas: 100% (10344/10344), done.

# %%
#yolo v7 
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 998, done.
# remote: Total 998 (delta 0), reused 0 (delta 0), pack-reused 998
# Receiving objects: 100% (998/998), 69.77 MiB | 29.44 MiB/s, done.
# Resolving deltas: 100% (467/467), done.

# %% [markdown]
# # yolov7 모델 돌려보기

# %%
# %pwd
# Out:
# '/content/dataset/val'

# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %%
# yolo v7 모델 돌리기 
# 성민씨 코드 
# 학습 모듈 실행

#경고 무시
#import warnings
#warnings.filterwarnings("ignore")
# 사용할 파이썬 파일
python_t = 'train.py'
# 사용할 데이터를 적어둔 yaml file
data = '/content/dataset/data.yaml'
# 사용할 모델 구조 (x>l>n>m>s)
cfg = '/content/yolov7/cfg/training/yolov7.yaml'

# 사용할 가중치
weights = './yolov7.pt'
# 학습 결과를 저장할 폴더 이름
name = '/content/yolov7/car_destroy/yolov7_val.'

# !python {python_t} --batch 16 --epochs 20 --data {data} --cfg {cfg} --weights {weights} --name {name}
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559690_as-0009398.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559694_as-0073537.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559695_as-0073537.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559696_as-0073537.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559698_as-3149926.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559701_as-2803939.jpg: negative labels
# val: Scanning '/content/dataset/val/labels' images and labels... 57814 found, 0 missing, 0 empty, 30599 corrupted:  85% 57814/67693 [01:14<00:11, 833.30it/s]val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559702_as-0042088.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559704_as-0042088.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559710_as-0016657.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559717_as-0016657.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559720_as-0016657.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559722_as-0016657.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559723_as-0016657.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559726_sc-181603.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559733_sc-1040902.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559734_sc-162522.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559736_sc-162522.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559741_as-2513356.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559743_as-0072339.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559744_as-0072339.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559745_as-0072339.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559752_as-0006979.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559753_as-0006979.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559762_as-0081682.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559763_as-0081682.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559764_as-0081682.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559765_as-0081682.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559769_as-0071110.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559772_as-0071110.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559773_as-0071110.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559779_sc-1026252.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559781_sc-1026252.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559783_as-3399566.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559798_as-0054445.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559799_sc-226655.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559804_sc-157913.jpg: negative labels
# val: Scanning '/content/dataset/val/labels' images and labels... 57899 found, 0 missing, 0 empty, 30629 corrupted:  86% 57899/67693 [01:14<00:11, 837.43it/s]val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559807_sc-113376.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559808_as-2526208.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559810_as-7282235.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559815_as-0002531.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559818_as-0019311.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559820_as-0019311.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559823_as-0005471.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (8,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559826_as-0005471.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559830_as-7248835.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559833_sc-210741.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559836_as-2623602.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559841_as-0036769.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559843_as-0036769.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559846_sc-205508.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559852_as-9071290.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559858_as-2862165.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559864_as-2854535.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559866_as-9077411.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559872_as-0059039.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559873_as-0059039.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559875_as-0059039.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559877_sc-1004615.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559878_sc-1004615.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559887_sc-159505.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0559894_as-0036534.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0
jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560632_as-0085063.jpg: negative labels
# val: Scanning '/content/dataset/val/labels' images and labels... 58585 found, 0 missing, 0 empty, 30892 corrupted:  87% 58585/67693 [01:15<00:11, 803.50it/s]val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560634_as-0085063.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560635_as-0085063.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560641_sc-191781.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560642_sc-191781.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560643_sc-191781.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560644_sc-191781.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560646_sc-191781.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560648_sc-191781.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560649_sc-191781.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560654_as-0073942.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560656_as-0098894.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560657_as-0098894.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560658_sc-1030810.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560659_sc-1030810.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560682_as-0048149.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560683_as-0048149.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560684_as-0048149.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560686_sc-161707.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560687_sc-161707.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560690_sc-161707.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560691_sc-1033984.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560693_sc-1033984.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560694_as-0004354.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560699_as-2641018.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (12,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560705_sc-1028305.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560719_as-0069578.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (9,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560721_as-0069578.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560723_as-0069578.jpg: negative labels
# val: Scanning '/content/dataset/val/labels' images and labels... 58666 found, 0 missing, 0 empty, 30920 corrupted:  87% 58666/67693 [01:15<00:11, 797.66it/s]val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560726_as-0074112.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560728_as-0074112.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560729_as-0074112.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560731_as-0074112.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560738_sc-1030253.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560742_sc-139966.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560748_as-3018592.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560749_as-2536304.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560750_as-2813315.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560752_as-2940916.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560757_sc-168601.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560761_as-0005194.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560767_sc-120282.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560769_sc-120282.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560770_sc-120282.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560774_as-2922427.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560776_sc-1040534.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560777_sc-181561.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560778_sc-181561.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560779_sc-181561.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560784_as-0086015.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560786_as-0086015.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560788_sc-152591.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560790_sc-152591.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560791_sc-152591.jpg: negative labels
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0560793_as-0084428.jpg: labels require 5 columns each
# ...
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631426_as-0006798.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631444_sc-188937.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (7,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631452_sc-188937.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631453_sc-123331.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631505_sc-119120.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631527_as-0025832.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631572_sc-1004729.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631576_as-0080210.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631677_sc-180773.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631691_as-0046502.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631720_sc-192164.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631724_sc-192164.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631825_sc-1028005.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631878_as-0086423.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631895_as-3567873.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631945_as-0058311.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (15,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0631981_sc-1005847.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632159_sc-123813.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632224_as-0041392.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632253_sc-167572.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (8,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632269_sc-183670.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632299_sc-181335.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632331_sc-1000755.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632352_sc-123718.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (13,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632601_as-0045592.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632613_as-0008985.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632659_sc-182232.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.
# val: WARNING: Ignoring corrupted image and/or label /content/dataset/val/images/0632664_sc-159441.jpg: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: Scanning '/content/dataset/val/labels' images and labels... 67693 found, 0 missing, 0 empty, 35494 corrupted: 100% 67693/67693 [01:26<00:00, 779.21it/s]
# val: New cache created: /content/dataset/val/labels.cache
#
# autoanchor: Analyzing anchors... anchors/target = 4.11, Best Possible Recall (BPR) = 0.9863
# Image sizes 640 train, 640 test
# Using 8 dataloader workers
# Logging results to /content/yolov7/car_destroy/yolov7_val.
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/19        8G    0.0563   0.01284   0.01435   0.08349        22       640: 100% 15928/15928 [1:19:32<00:00,  3.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   0% 0/1007 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1007/1007 [03:46<00:00,  4.45it/s]
#                  all       32199       90741       0.269       0.236        0.17      0.0642
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/19     10.6G   0.05093   0.01278    0.0109   0.07461        26       640: 100% 15928/15928 [1:15:51<00:00,  3.50it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1007/1007 [03:05<00:00,  5.44it/s]
#                  all       32199       90741       0.297       0.263       0.202      0.0783
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2