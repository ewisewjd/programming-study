# %% [markdown]
# # seaborn
# - 시각화 라이브러리

# %% [markdown]
# !pip install seaborn

# %%
# !pip install seaborn
# Out:
# ...
#      -------------------------------------- 293.3/293.3 kB 2.6 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
import seaborn as sns
df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
https://github.com/mwaskom/seaborn-data

# %%
tips_df = sns.load_dataset("tips")

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips_df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tips_df.dtype
#
# File c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
tips_df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips_df.shape
# Out:
# (244, 7)

# %%
sns.boxplot(tips_df)
# Out:
# <Axes: >

# %%
#total_bill이 높을 수록 => tip도 많이 받을 가능성이 높다. 
#total_bill이 높게나오는 (1)요일,

# 어느 요일에 매출이 잘 나올까
sns.boxplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips_df, hue="smoker",palette="Set3")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=tips_df, x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # LMPLOT( LINEAR MODEL PLOT)
# - 컬럼들간의 선형, 상관관계를 확인할 수 있는 그래프
# - 회귀분석 (REGRESSION ANALYSIS)
#     - 독립변인이 종속변인에 영향을 미치는지 알아보고자 할때 실시하는 분석방법
#
# - 상관관계
#     - -1~1 사이의 값을 갖는데요, 0에 가까울 수록 두 변수는 관계가 없음을 나타냅니다.
#
# EX)
# -  키와 몸무게가 상관관계까 있는가=> 키가 클수록 몸무게도 많이 나가는가? ==> 1에 가까운 모습을 보여주겠죠
#
# - 한달에 읽는 책 권수와 경제적 자유는 상관관계인가? => KB 금융 부자 리포트
#
# - MBTI와 부자가 되는 것은 관계가 있는가?
# - 테이블 전체 계산 금액이 클수록 -> 팁도 많이 내눈가(팁: LABEL, 정답, 결과값)

# %%
sns.lmplot(data=tips_df, x="total_bill",y="tip" ,hue="smoker") #y값이 종속변수가 되는 값

# %%
sns.lmplot(data=tips_df, x="total_bill", y="tip")
https://www.kaggle.com/code/sanjanabasu/tips-dataset

# %% [markdown]
# # 비행기 데이터

# %% [markdown]
# flights=sns.load_dataset("flight")

# %%
flights=sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#flights=flights.pivot("month","year","passengers")
sns.heatmap(flights, annot=True, fmt="d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 #flights=flights.pivot("month","year","passengers")
# ----> 2 sns.heatmap(flights, annot=True, fmt="d")
#
# File c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %% [markdown]
# # pair plot

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue="species")

# Sepal Length:꽃받침의 길이 정보
# Sepal Width: 꽃받침의 너비 정보 
# Petal Length:꽃잎의 길이 정보 
# Petal Width:꽃잎의 너비 정보

# %%
sns.pairplot(iris, vars=("sepal_width","sepal_length"))

# %%
iris.corr(numeric_only=True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# # folium
# - 지도 시각화

# %%
# !pip install folium
# Out:
# ...
#      -------------------------------------- 102.3/102.3 kB 2.0 MB/s eta 0:00:00
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#      ---------------------------------------- 62.8/62.8 kB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.7/96.7 kB 2.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import folium

# %%
folium.Map(location=[37.5488619, 127.1753687], zoom_start=15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 타이타닉 시각화

# %% [markdown]
# https://drive.google.com/drive/u/1/folders/1bOwI2LiRKTQlJu3QV-9WnWG85Fn4AKcf

# %%
import pandas as pd

df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['Age'],bins=10)
# Out:
# C:\Users\jung\AppData\Local\Temp\ipykernel_21436\3335810855.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],bins=10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(x="Pcalss", y="Survived", data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 sns.distplot(x="Pcalss", y="Survived", data=df)
#
# TypeError: distplot() got an unexpected keyword argument 'y'

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sns.barplot(x='Pclass', y='Survived', data=df["Sex"])
#
# File c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...

# %%
sns.barplot(x='Pclass', y='Survived', data=df[df['Sex']=="male"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
bar1=sns.barplot(x='Pclass', y='Survived', data=df[df['Sex']=="male"],color=)
bar2=sns.barplot(x='Pclass', y='Survived', data=df[df['Sex']=="female"],color=)

# %%
#나이를 한번 구해보겠습니다. 
df['Age'].unique()
def set_age_category(age):
    category=""
    
    if age<= 5:
        category="baby"
    elif age<=18:
        category="student"
    elif age<= 30:
        category="young adult"
    elif age<=60:
        category="adult"
    else:
        category="elder"
        
    return category

df['Age_Category']=df['Age'].apply(lambda x: set_age_category(x))

# %%
df[['Age','Age_Category']]
# Out:
#       Age Age_Category
# 0    22.0  young adult
# 1    38.0        adult
# 2    26.0  young adult
# 3    35.0        adult
# 4    35.0        adult
# ..    ...          ...
# 886  27.0  young adult
# 887  19.0  young adult
# 888   NaN        elder
# 889  26.0  young adult
# 890  32.0        adult
#
# [891 rows x 2 columns]

# %%
sns.barplot(x="Age_Category", y="Survived",data=df,hue="Sex")
# Out:
# <Axes: xlabel='Age_Category', ylabel='Survived'>

# %%
sns.barplot(x='Age_Category', y="Survived", data=df, hue="Sex")
# Out:
# <Axes: xlabel='Age_Category', ylabel='Survived'>

# %%
sns.barplot(data=df, x='Age_Category', y='Survived', hue='Sex', 
            order=['children', 'student', 'young adult', 'adult', 'elder'])
# Out:
# <Axes: xlabel='Age_Category', ylabel='Survived'>

# %%
# sns.barplot(x='Age_Category', y="Survived", data=df, hue="Sex")
# 그래프에서 나이순으로 표현을 해주세요.

orders=['baby', 'student', 'young adult', 'adult', 'elder']
sns.barplot(data=df, x='Age_Category', y='Survived', hue='Sex', order=orders)
# Out:
# <Axes: xlabel='Age_Category', ylabel='Survived'>

# %%
# 남성과 여성별로 나이대의 생존확률 분포도를 나타내시오 
sns.barplot(x='Sex', y='Survived', data=df, hue='Age_Category')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(x="Sex",y="Survived", data=df, hue="Age_Category")
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(x="Survived", y="Pclass", data=df, orient='h')
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# # violin plot

# %%
sns.violinplot(y="Age", data=df)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(x="Sex",y="Age", data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # subplot을 이용하여

# %%
columns=["Survived","Pclass","Sex","Age_Category"]

for index, data in enumerate(columns):
    print(index, data)
# Out:
# 0 Survived
# 1 Pclass
# 2 Sex
# 3 Age_Category

# %%
columns=["Survived","Pclass","Sex","Age_Category"]

fig, ax=plt.subplots(1,4, figsize=(16,8))

for  index, column in enumerate(columns):
    sns.countplot(x=column, data=df, ax=ax(index))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 6
#       3 fig, ax=plt.subplots(1,4, figsize=(16,8))
#       5 for  index, column in enumerate(columns):
# ----> 6     sns.countplot(x=column, data=df, ax=ax(index))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
columns = ["Survived", "Pclass", "Sex", "Age_Category"]

fig, ax = plt.subplots(1, 4, figsize=(16,8))


for index, column in enumerate(columns):
    sns.countplot(x=column, data=df, ax=ax[index])

# %%
columns = [ "Pclass", "Sex", "Age_Category"]

fig, ax = plt.subplots(1, 3, figsize=(16,8))


for index, column in enumerate(columns):
    sns.barplot(x=column,y="Survived", data=df, ax=ax[index])

# %% [markdown]
# # scatterplot

# %%
sns.scatterplot(x="Age", y="Fare", data=df, hue="Survived")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
corr_df=df.corr(numeric_only=True)

sns.heatmap(corr_df,annot=True, fmt='.1f',cmap="YlGnBu")
# Out:
# <Axes: >

# %%
corr_df = df.corr(numeric_only=True)
sns.heatmap(corr_df, annot=True, fmt='.1f', cmap="YlGnBu")
# Out:
# <Axes: >
