# %% [markdown]
# # 서울 아파트 분양가 분석

# %%
# library import 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# csv read
first_file_name='전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv'
last_file_name='주택도시보증공사_전국 평균 분양가격(2019년 12월).csv'

# %%
# csv read
first_file_name = '전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv' #2013~2015.08
last_file_name = '주택도시보증공사_전국 평균 분양가격(2019년 12월).csv' #2015.09~2019.12

df_first = pd.read_csv(first_file_name, encoding="euc-kr") # utf-8
df_last = pd.read_csv(last_file_name, encoding="euc-kr")

display(df_first, df_last)
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월
# 0   서울     18189    17925    17925    18016    18098    19446    18867  \
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# 12  전북      6282     6281     5946     5966     6277     6306     6351
# 13  전남      5678     5678     5678     5696     5736     5656     5609
# 14  경북      6168     6168     6234     6317     6412     6409     6554
# 15  경남      6473     6485     6502     6610     6599     6610     6615
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월
# 0     18742    19274  ...     20242     20269    20670    20670    19415  \
# 1      9457     9411  ...      9208      9208     9204     9235     9279
# 2      8360     8370  ...      8439      8253     8327     8416     8441
# 3      9974     9973  ...     10020     10020    10017     9876     9876
# 4      7612     7622  ...      7752      7748     7752     7756     7861
# 5      8333     8333  ...      8067      8067     8067     8067     8067
# 6      8153     8493  ...      8891      8891     8526     8526     8629
# 7     10124    10134  ...     10356     10379    10391    10355    10469
# 8      8067     8141  ...      8592      8560     8560     8560     8555
# 9      6268     6268  ...      6365      6365     6348     6350     6182
# 10     6586     6586  ...      6724      6743     6749     6747     6783
# 11     6805     6914  ...      6940      6989     6976     6980     7161
# 12     6319     6436  ...      6583      6583     6583     6583     6542
# 13     5780     5685  ...      5768      5784     5784     5833     5825
# 14     6556     6563  ...      6881      6989     6992     6953     6997
# 15     6613     6606  ...      7125      7332     7592     7588     7668
# 16     7914     7914  ...      7724      7739     7739     7739     7826
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0     18842    18367    18374    18152    18443
# 1      9327     9345     9515     9559     9581
# 2      8446     8568     8542     8542     8795
# 3      9938    10551    10443    10443    10449
# 4      7914     7877     7881     8089     8231
# 5      8145     8272     8079     8079     8079
# 6      9380     9192     9190     9190     9215
# 7     10684    10685    10573    10518    10573
# 8      8546     8546     8671     8669     8695
# 9      6924     6846     6986     7019     7008
# 10     6790     6805     6682     6601     6603
# 11     7017     6975     6939     6935     6942
# 12     6551     6556     6601     6750     6580
# 13     5940     6050     6243     6286     6289
# 14     7006     6966     6887     7035     7037
# 15     7683     7717     7715     7723     7665
# 16     7285     7285     7343     7343     7343
#
# [17 rows x 22 columns]
#      지역명               규모구분    연도   월 분양가격(㎡)
# 0     서울                 전체  2015  10    5841
# 1     서울         전용면적 60㎡이하  2015  10    5652
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4     서울        전용면적 102㎡초과  2015  10    5879
# ...   ..                ...   ...  ..     ...
# 4330  제주                 전체  2019  12    3882
# 4331  제주         전용면적 60㎡이하  2019  12     NaN
# 4332  제주   전용면적 60㎡초과 85㎡이하  2019  12    3898
# 4333  제주  전용면적 85㎡초과 102㎡이하  2019  12     NaN
# 4334  제주        전용면적 102㎡초과  2019  12    3601
#
# [4335 rows x 5 columns]

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %%
df_last.isna().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# dtype: int64

# %%
df_last['분양가격'] = pd.to_numeric(df_last['분양가격(㎡)'], errors='coerce')

# errors
# - ignore: 변경할 수 없는 데이터면 -> 원본 데이터 그대로 반환
# - coerce: 변경할 수 없는 데이터면 -> NaN 으로 반환.
# - raise: numeric으로 변경할 수 없는 경우 오류가 발생하며 작업 중단

# %%
df_last['평당분양가격'] = df_last['분양가격'] * 3.3 # (1평=> 3.3m2)

# %%
df_last.head(5)
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0  서울                 전체  2015  10    5841  5841.0  19275.3
# 1  서울         전용면적 60㎡이하  2015  10    5652  5652.0  18651.6
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882  5882.0  19410.6
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721  5721.0  18879.3
# 4  서울        전용면적 102㎡초과  2015  10    5879  5879.0  19400.7

# %%
df_first.head(5)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월
# 0  서울     18189    17925    17925    18016    18098    19446    18867  \
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월
# 0    18742    19274  ...     20242     20269    20670    20670    19415  \
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
# 2     8446     8568     8542     8542     8795
# 3     9938    10551    10443    10443    10449
# 4     7914     7877     7881     8089     8231
#
# [5 rows x 22 columns]

# %%
df_last['분양가격'].describe()
# Out:
# count     3957.000000
# mean      3238.128633
# std       1264.309933
# min       1868.000000
# 25%       2441.000000
# 50%       2874.000000
# 75%       3561.000000
# max      12728.000000
# Name: 분양가격, dtype: float64

# %%
df_last['규모구분'].unique()
# Out:
# array(['전체', '전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
# 전용면적 제거
# 이하 제거
# 초과 => ~
# array(['전체', '60㎡', '60㎡~85㎡', '85㎡~102㎡', '102㎡~'], dtype=object)

df_last['전용면적'] = df_last['규모구분']

# %%
df_last['분양가격'] = pd.to_numeric(df_last['분양가격(㎡)'], errors='coerce')

# errors
# - ignore: 변경할 수 없는 데이터면 -> 원본 데이터 그대로 반환
# - coerce: 변경할 수 없는 데이터면 -> 그냥 지워버려.
# - raise: numeric으로 변경할 수 없는 경우 오류가 발생하며 작업 중단

# %%
df_last['평당분양가격']=df_last['분양가격']*3.3

# %%
df_last.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_last_head(5)
#
# NameError: name 'df_last_head' is not defined

# %%
df_last['규모구분'].unique()

# %%
# 전용면적 제거 
# 이하 제거 
# 초과 => ~
# array=(['전체','60m','60m~85','85m~102','102m~'], dtype=object)

df_last['전용면적']=df_last['규모구분'].str.replace["전용면적",""]
df_last['전용면적']=df_last['규모구분'].str.replace["이하",""]
df_last['전용면적']=df_last['규모구분'].str.replace["초과",""]
df_last['전용면적']=df_last['규모구분'].str.replace[" ",""]

df_last['전용면적']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       1 # 전용면적 제거
#       2 # 이하 제거
#       3 # 초과 => ~
#       4 # array=(['전체','60m','60m~85','85m~102','102m~'], dtype=object)
# ----> 6 df_last['전용면적']=df_last['규모구분'].str.replace["전용면적",""]
#       7 df_last['전용면적']=df_last['규모구분'].str.replace["이하",""]
#       8 df_last['전용면적']=df_last['규모구분'].str.replace["초과",""]
#
# TypeError: 'method' object is not subscriptable

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
#  20  2015년7월   17 non-null     int64
#  21  2015년8월   17 non-null     int64
# dtypes: int64(21), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 규모구분 데이터에서 
# (1) 전용면적,이하 문자열을 제거하고
# (2) 초과 문자열을 ~로 변경
# (3) 빈 문자열 제거
# array(['전체', '60㎡', '60㎡~85㎡', '85㎡~102㎡', '102㎡~'], dtype=object)

df_last['전용면적'] = df_last['규모구분'].str.replace("전용면적", "")
df_last['전용면적'] = df_last['전용면적'].str.replace("이하", "")
df_last['전용면적'] = df_last['전용면적'].str.replace("초과", "~")
df_last['전용면적'] = df_last['전용면적'].str.replace(" ", "")

df_last['전용면적']
# Out:
# 0             전체
# 1            60㎡
# 2        60㎡~85㎡
# 3       85㎡~102㎡
# 4          102㎡~
#           ...
# 4330          전체
# 4331         60㎡
# 4332     60㎡~85㎡
# 4333    85㎡~102㎡
# 4334       102㎡~
# Name: 전용면적, Length: 4335, dtype: object

# %%
def do_some(str):
    return str.replace(' ', '').replace('전용면적','').replace('이하', '').replace('초과', '~')


df_last['전용면적'] = df_last['규모구분'].apply(lambda x: do_some(x))

# %%
df_last = df_last.drop(['분양가격(㎡)', '규모구분'], axis=1)
df_last
# Out:
#      지역명    연도   월    분양가격   평당분양가격      전용면적
# 0     서울  2015  10  5841.0  19275.3        전체
# 1     서울  2015  10  5652.0  18651.6       60㎡
# 2     서울  2015  10  5882.0  19410.6   60㎡~85㎡
# 3     서울  2015  10  5721.0  18879.3  85㎡~102㎡
# 4     서울  2015  10  5879.0  19400.7     102㎡~
# ...   ..   ...  ..     ...      ...       ...
# 4330  제주  2019  12  3882.0  12810.6        전체
# 4331  제주  2019  12     NaN      NaN       60㎡
# 4332  제주  2019  12  3898.0  12863.4   60㎡~85㎡
# 4333  제주  2019  12     NaN      NaN  85㎡~102㎡
# 4334  제주  2019  12  3601.0  11883.3     102㎡~
#
# [4335 rows x 6 columns]

# %%
#지역별 평당 분양가의 기술통계값을 보고 싶다. 
df_last.groupby(['지역명'])['평당분양가격'].describe()
# Out:
#      count          mean          std      min        25%       50%
# 지역명
# 강원   242.0   7890.750000  1044.359840   6639.6   7165.950   7581.75  \
# 경기   250.0  13356.895200  1969.310711  10160.7  11729.025  13168.65
# 경남   247.0   9268.778138  1356.695327   7260.0   8233.500   9187.20
# 경북   241.0   8376.536515   850.823275   6949.8   7728.600   8335.80
# 광주   201.0   9951.535821  1506.593261   7428.3   9068.400   9527.10
# 대구   242.0  11980.895455  2018.395637   8259.9  10399.950  11904.75
# 대전   198.0  10253.333333  2245.370020   8002.5   8580.000   9401.70
# 부산   250.0  12087.121200  1447.322754   9669.0  10709.325  12338.70
# 서울   250.0  23599.976400  3969.953218  16701.3  21318.825  22497.75
# 세종   237.0   9796.516456  1096.551246   8487.6   8906.700   9197.10
# 울산   149.0  10014.902013   899.543667   7992.6   9484.200  10127.70
# 인천   246.0  11915.320732  1642.963530   9537.0  10808.325  11378.40
# 전남   248.0   7565.316532   773.929820   6289.8   7098.300   7585.05
# 전북   248.0   7724.235484   868.364876   6270.0   7248.450   7659.30
# 제주   219.0  11241.276712  2351.630010   7342.5   9929.700  10787.70
# 충남   239.0   8233.651883   741.954128   6926.7   7585.050   8134.50
# 충북   250.0   7634.655600   796.759331   6164.4   6969.600   7543.80
#
#            75%      max
# 지역명
# 강원    8281.350  11873.4
# 경기   14600.025  18711.0
# 경남    9698.700  14199.9
# 경북    8824.200  11408.1
# 광주   10800.900  16107.3
# 대구   13330.350  17021.4
# 대전   11615.175  16094.1
# 부산   12972.300  15255.9
# 서울   25072.575  42002.4
# 세종   10388.400  12972.3
# 울산   10474.200  11860.2
# 인천   12480.600  17120.4
# 전남    7923.300  10074.9
# 전북    8241.750  10071.6
# 제주   12553.200  18024.6
# 충남    8768.100  10563.3
# 충북    8250.000   9421.5

# %%
#전용 면적별 평당분양가격의 평균값은 어떻게 될까
df_last.groupby('전용면적')['평당분양가격'].mean()
# Out:
# 전용면적
# 102㎡~       11517.705634
# 60㎡         10375.137421
# 60㎡~85㎡     10271.040071
# 85㎡~102㎡    11097.599573
# 전체          10276.086207
# Name: 평당분양가격, dtype: float64

# %%
# 전용면적별 평당분양가격의 평균값은 어떻게 될까?
df_last.groupby(['전용면적'])['평당분양가격'].mean()
# Out:
# 전용면적
# 102㎡~       11517.705634
# 60㎡         10375.137421
# 60㎡~85㎡     10271.040071
# 85㎡~102㎡    11097.599573
# 전체          10276.086207
# Name: 평당분양가격, dtype: float64

# %%
# 지역별 전용면적의 평균분양가격 평균가를 df로 나타내시오
df_last.groupby(['지역명','전용면적'])['평당분양가격'].mean()
# Out:
# 지역명  전용면적
# 강원   102㎡~       8311.380000
#      60㎡         7567.098000
#      60㎡~85㎡     7485.588000
#      85㎡~102㎡    8749.557143
#      전체          7477.536000
#                     ...
# 충북   102㎡~       8195.352000
#      60㎡         7103.118000
#      60㎡~85㎡     7264.488000
#      85㎡~102㎡    8391.306000
#      전체          7219.014000
# Name: 평당분양가격, Length: 85, dtype: float64

# %%
# 지역별 전용면적의 평균분양가격 평균가를 df로 나타내시오
df_last.groupby(['지역명','전용면적'])['평당분양가격'].mean().unstack()
# Out:
# 전용면적         102㎡~           60㎡       60㎡~85㎡      85㎡~102㎡            전체
# 지역명
# 강원     8311.380000   7567.098000   7485.588000   8749.557143   7477.536000
# 경기    14771.790000  13251.744000  12523.566000  13677.774000  12559.602000
# 경남    10358.363265   8689.175000   8618.676000  10017.612000   8658.672000
# 경북     9157.302000   7883.172000   8061.372000   8773.814634   8078.532000
# 광주    11041.532432   9430.666667   9910.692000   9296.100000   9903.630000
# 대구    13087.338000  11992.068000  11778.690000  11140.642857  11771.298000
# 대전    14876.871429   9176.475000   9711.372000   9037.430769   9786.018000
# 부산    13208.250000  11353.782000  11864.820000  12072.588000  11936.166000
# 서울    23446.038000  23212.794000  22786.830000  25943.874000  22610.346000
# 세종    10106.976000   9323.927027   9775.458000   9847.926000   9805.422000
# 울산     9974.448000   9202.106897  10502.531707   8861.007692  10492.712195
# 인천    14362.030435  11241.318000  11384.406000  11527.560000  11257.026000
# 전남     8168.490000   7210.170000   7269.240000   7908.862500   7283.562000
# 전북     8193.570000   7609.932000   7271.352000   8275.781250   7292.604000
# 제주    10522.787234  14022.221053  10621.314000  10709.082353  10784.994000
# 충남     8689.169388   7911.156000   7818.954000   9120.045000   7815.324000
# 충북     8195.352000   7103.118000   7264.488000   8391.306000   7219.014000

# %%
# 지역명이 인덱스, 연도별이 컬럼 -> 연도별 평당 분양가격의 평균값은?

df_last.groupby(['연도', '지역명'])['평당분양가격'].mean().unstack().transpose()
# Out:
# 연도        2015          2016          2017          2018          2019
# 지역명
# 강원    7188.060   7162.903846   7273.560000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12304.980000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8786.760000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8280.800000   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9613.977551   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12206.700000  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9957.158491  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11560.680000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21831.060000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.505556  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10666.935714  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11640.600000  11881.532143  13249.775000
# 전남    6798.880   6936.600000   7372.920000   7929.845000   8219.275862
# 전북    7110.400   6906.625000   7398.973585   8174.595000   8532.260000
# 제주    7951.075   9567.480000  12566.730000  11935.968000  11828.469231
# 충남    7689.880   7958.225000   8198.422222   8201.820000   8748.840000
# 충북    6828.800   7133.335000   7473.120000   8149.295000   7970.875000

# %%
df_last_pivot=pd.pivot_table(df_last, index=['전용면적'],columns=['연도'],values=['평당분양가격'])

# %%
df_last_pivot
# Out:
#                평당분양가격
# 연도               2015          2016          2017          2018          2019
# 전용면적
# 102㎡~     9837.226667  10388.728272  11334.484615  11445.574576  13331.520968
# 60㎡       8951.525000   9398.876119  10246.133333  10844.409783  11506.803371
# 60㎡~85㎡   8891.817647   9295.986765   9825.000000  10650.611823  11677.201531
# 85㎡~102㎡  9518.506250  10122.355435  10540.402454  11441.707895  12980.676923
# 전체        8893.047059   9293.042647   9901.270588  10675.825123  11602.715816

# %%
df_last_pivot['평당분양가격'][2015]
# Out:
# 전용면적
# 102㎡~       9837.226667
# 60㎡         8951.525000
# 60㎡~85㎡     8891.817647
# 85㎡~102㎡    9518.506250
# 전체          8893.047059
# Name: 2015, dtype: float64

# %%
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df_last.groupby(['전용면적'])['평당분양가격'].mean().sort_values().plot.bar()
# Out:
# <Axes: xlabel='전용면적'>

# %%
df_last.groupby(['전용면적'])['평당분양가격'].mean().sort_values().plot.bar()
# Out:
# <Axes: xlabel='전용면적'>

# %%
df_last.groupby(['연도'])['평당분양가격'].mean().plot()
# Out:
# <Axes: xlabel='연도'>
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_last.groupby(['연도'])['평당분양가격'].mean().plot()

# %%
df_last.pivot_table(index='월',columns='연도',values='평당분양가격').plot.box()
# Out:
# <Axes: >

# %%
df_last.pivot_table(index='월', columns=['연도','전용면적'], values='평당분양가격').plot.box()
# Out:
# <Axes: >
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 연도별 월에 따른 평당분양가격 변화 추이
df_last.pivot_table(index="월", columns=["연도"], values="평당분양가격").plot(figsize=(20,5), rot=90)
# Out:
# <Axes: xlabel='월'>
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\jung\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns

# %%
df_last_sorted=df_last.sort_values('평당분양가격')
sns.barplot(data=df_last, x="지역명",y='평당분양가격')
# Out:
# <Axes: xlabel='지역명', ylabel='평당분양가격'>

# %%
df_last_sorted=df_last.sort_values(by='평당분양가격',ascending=False)
sns.barplot(data=df_last_sorted, x="지역명",y='평당분양가격')
# Out:
# <Axes: xlabel='지역명', ylabel='평당분양가격'>

# %%
max_price=df_last['평당분양가격'].max()

# %%
df_last[df_last['평당분양가격']==max_price]
# Out:
#      지역명    연도   월     분양가격   평당분양가격      전용면적
# 3743  서울  2019   6  12728.0  42002.4  85㎡~102㎡
# 3828  서울  2019   7  12728.0  42002.4  85㎡~102㎡
# 3913  서울  2019   8  12728.0  42002.4  85㎡~102㎡
# 3998  서울  2019   9  12728.0  42002.4  85㎡~102㎡
# 4083  서울  2019  10  12728.0  42002.4  85㎡~102㎡
# 4168  서울  2019  11  12728.0  42002.4  85㎡~102㎡
# 4253  서울  2019  12  12728.0  42002.4  85㎡~102㎡

# %%
df_first
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월
# 0   서울     18189    17925    17925    18016    18098    19446    18867  \
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# 12  전북      6282     6281     5946     5966     6277     6306     6351
# 13  전남      5678     5678     5678     5696     5736     5656     5609
# 14  경북      6168     6168     6234     6317     6412     6409     6554
# 15  경남      6473     6485     6502     6610     6599     6610     6615
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월
# 0     18742    19274  ...     20242     20269    20670    20670    19415  \
# 1      9457     9411  ...      9208      9208     9204     9235     9279
# 2      8360     8370  ...      8439      8253     8327     8416     8441
# 3      9974     9973  ...     10020     10020    10017     9876     9876
# 4      7612     7622  ...      7752      7748     7752     7756     7861
# 5      8333     8333  ...      8067      8067     8067     8067     8067
# 6      8153     8493  ...      8891      8891     8526     8526     8629
# 7     10124    10134  ...     10356     10379    10391    10355    10469
# 8      8067     8141  ...      8592      8560     8560     8560     8555
# 9      6268     6268  ...      6365      6365     6348     6350     6182
# 10     6586     6586  ...      6724      6743     6749     6747     6783
# 11     6805     6914  ...      6940      6989     6976     6980     7161
# 12     6319     6436  ...      6583      6583     6583     6583     6542
# 13     5780     5685  ...      5768      5784     5784     5833     5825
# 14     6556     6563  ...      6881      6989     6992     6953     6997
# 15     6613     6606  ...      7125      7332     7592     7588     7668
# 16     7914     7914  ...      7724      7739     7739     7739     7826
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0     18842    18367    18374    18152    18443
# 1      9327     9345     9515     9559     9581
# 2      8446     8568     8542     8542     8795
# 3      9938    10551    10443    10443    10449
# 4      7914     7877     7881     8089     8231
# 5      8145     8272     8079     8079     8079
# 6      9380     9192     9190     9190     9215
# 7     10684    10685    10573    10518    10573
# 8      8546     8546     8671     8669     8695
# 9      6924     6846     6986     7019     7008
# 10     6790     6805     6682     6601     6603
# 11     7017     6975     6939     6935     6942
# 12     6551     6556     6601     6750     6580
# 13     5940     6050     6243     6286     6289
# 14     7006     6966     6887     7035     7037
# 15     7683     7717     7715     7723     7665
# 16     7285     7285     7343     7343     7343
#
# [17 rows x 22 columns]

# %%
#가로 방향의 데이터 프레임=> 세로방향으로 전환
# 가로 방향의 데이터 프레임 => 세로 방향으로 전환
df_first_melt = df_first.melt(id_vars='지역', var_name='기간', value_name="평당분양가격")
df_first_melt
# Out:
#      지역        기간  평당분양가격
# 0    서울  2013년12월   18189
# 1    부산  2013년12월    8111
# 2    대구  2013년12월    8080
# 3    인천  2013년12월   10204
# 4    광주  2013년12월    6098
# ..   ..       ...     ...
# 352  전북   2015년8월    6580
# 353  전남   2015년8월    6289
# 354  경북   2015년8월    7037
# 355  경남   2015년8월    7665
# 356  제주   2015년8월    7343
#
# [357 rows x 3 columns]

# %%
# 2013년 1월
# 2013년 2월

date="2013년 12월"

# 숫자 데이터만 표현
year=date.split("년")[0]

month=date.split("년")[1].replace("월","")

print(year,month)
# Out:
# 2013  12

# %%
def parse_year(date):
    year=date.split("년")[0]
    return year

def parse_month(date):
    month=date.split("년")[1].replace("월","")
    return month

# %%
# 기간 컬럼에서 => 년, 월로 데이터를 각각 컬럼 별로 분리
df_first_melt['연도'] = df_first_melt['기간'].apply(parse_year)
df_first_melt['월'] = df_first_melt['기간'].apply(parse_month)

# %%
df_first_melt
# Out:
#      지역        기간  평당분양가격    연도   월
# 0    서울  2013년12월   18189  2013  12
# 1    부산  2013년12월    8111  2013  12
# 2    대구  2013년12월    8080  2013  12
# 3    인천  2013년12월   10204  2013  12
# 4    광주  2013년12월    6098  2013  12
# ..   ..       ...     ...   ...  ..
# 352  전북   2015년8월    6580  2015   8
# 353  전남   2015년8월    6289  2015   8
# 354  경북   2015년8월    7037  2015   8
# 355  경남   2015년8월    7665  2015   8
# 356  제주   2015년8월    7343  2015   8
#
# [357 rows x 5 columns]

# %%
#df_last에 전용면적 '전체'데이터만 가져오시오.
# 단, 컬럼을 지역명, 연도,월, 평당 분양가격만 가져오시오. 

df_last[df_last['전용면적']=='전체'][['지역명','연도','월','평당분양가격']]
df_last_prepare=df_last.loc[df_last['전용면적']=='전체',['지역명','연도','월','평당분양가격']]

df_last_prepare
# Out:
#      지역명    연도   월   평당분양가격
# 0     서울  2015  10  19275.3
# 5     인천  2015  10  10437.9
# 10    경기  2015  10  10355.4
# 15    부산  2015  10  10269.6
# 20    대구  2015  10   8850.6
# ...   ..   ...  ..      ...
# 4310  전북  2019  12   8144.4
# 4315  전남  2019  12   8091.6
# 4320  경북  2019  12   9616.2
# 4325  경남  2019  12  10107.9
# 4330  제주  2019  12  12810.6
#
# [867 rows x 4 columns]

# %%
df_first_melt.columns=['지역명','기간','평당분양가격','연도','월']

# %%
df_first_prepare=df_first_melt[['지역명','평당분양가격','연도','월']]

df_first_prepare
# Out:
#     지역명  평당분양가격    연도   월
# 0    서울   18189  2013  12
# 1    부산    8111  2013  12
# 2    대구    8080  2013  12
# 3    인천   10204  2013  12
# 4    광주    6098  2013  12
# ..   ..     ...   ...  ..
# 352  전북    6580  2015   8
# 353  전남    6289  2015   8
# 354  경북    7037  2015   8
# 355  경남    7665  2015   8
# 356  제주    7343  2015   8
#
# [357 rows x 4 columns]

# %%
df_first_prepare # 2013 ~2015
df_last_prepare # 2015~

#merge, concat,join,...

df_final=pd.concat([df_first_prepare,df_last_prepare])
df_final
# Out:
#      지역명   평당분양가격    연도   월
# 0     서울  18189.0  2013  12
# 1     부산   8111.0  2013  12
# 2     대구   8080.0  2013  12
# 3     인천  10204.0  2013  12
# 4     광주   6098.0  2013  12
# ...   ..      ...   ...  ..
# 4310  전북   8144.4  2019  12
# 4315  전남   8091.6  2019  12
# 4320  경북   9616.2  2019  12
# 4325  경남  10107.9  2019  12
# 4330  제주  12810.6  2019  12
#
# [1224 rows x 4 columns]

# %%
df_final

# %%
pd.pivot_table(df_final, index='연도',columns='지역명')
# Out:
#                      월
# 지역명                 강원                경기                경남                경북
# 연도
# 2015              11.0              11.0              11.0              11.0  \
# 2016               6.5               6.5               6.5               6.5
# 2017               6.5               6.5               6.5               6.5
# 2018               6.5               6.5               6.5               6.5
# 2019               6.5               6.5               6.5               6.5
# 2013              12.0              12.0              12.0              12.0
# 2014  10288065758426.0  10288065758426.0  10288065758426.0  10288065758426.0
# 2015        1543209.75        1543209.75        1543209.75        1543209.75
#
#
# 지역명                 광주                대구                대전                부산
# 연도
# 2015              11.0              11.0              11.0              11.0  \
# 2016               6.5               6.5               6.5               6.5
# 2017               6.5               6.5               6.5               6.5
# 2018               6.5               6.5               6.5               6.5
# 2019               6.5               6.5               6.5               6.5
# 2013              12.0              12.0              12.0              12.0
# 2014  10288065758426.0  10288065758426.0  10288065758426.0  10288065758426.0
# 2015        1543209.75        1543209.75        1543209.75        1543209.75
#
#                                           ...        평당분양가격
# 지역명                 서울                세종  ...            부산         서울
# 연도                                        ...
# 2015              11.0              11.0  ...  10307.000000  19725.200  \
# 2016               6.5               6.5  ...  10429.925000  20663.500
# 2017               6.5               6.5  ...  11577.900000  21375.900
# 2018               6.5               6.5  ...  12997.875000  22889.350
# 2019               6.5               6.5  ...  13116.400000  26131.050
# 2013              12.0              12.0  ...   8111.000000  18189.000
# 2014  10288065758426.0  10288065758426.0  ...   9180.166667  18997.250
# 2015        1543209.75        1543209.75  ...   9380.625000  19116.625
#
#
# 지역명             세종            울산            인천           전남           전북
# 연도
# 2015   8750.500000  10052.900000  10484.100000  6317.300000  6703.400000  \
# 2016   8860.500000  10208.550000  10532.500000  6488.625000  6417.950000
# 2017   9135.300000  11345.100000  10736.700000  7187.700000  7057.800000
# 2018  10354.850000  10241.400000  11273.900000  7789.100000  7625.750000
# 2019  11078.925000  10022.100000  12634.875000  7902.400000  8196.650000
# 2013   7601.000000   8090.000000  10204.000000  5678.000000  6282.000000
# 2014   8085.333333   8361.666667  10074.833333  5718.916667  6362.333333
# 2015   8600.250000   8981.000000  10199.125000  6031.250000  6593.250000
#
#
# 지역명             제주           충남        충북
# 연도
# 2015   7405.200000  7114.800000  6645.100
# 2016   9129.175000  7330.675000  6770.225
# 2017  10830.900000  7456.200000  6762.600
# 2018  11890.725000  8012.675000  7874.075
# 2019  12137.950000  8606.950000  7574.600
# 2013   7674.000000  6365.000000  6589.000
# 2014   7855.166667  6681.583333  6620.000
# 2015   7487.875000  6990.625000  6720.000
#
# [8 rows x 34 columns]

# %%
df_seoul=df_final[df_final["지역명"]=="서울"]

# %%
sns.barplot(data=df_seoul, x="연도",y='평당분양가격')
# Out:
# <Axes: xlabel='연도', ylabel='평당분양가격'>

# %%
plt.figure(figsize=(16,10))
sns.boxplot(data=df_final, x='지역명',y='평당분양가격')
# Out:
# <Axes: xlabel='지역명', ylabel='평당분양가격'>

# %% [markdown]
# ![image.png](attachment:image.png)
